# %%
import numpy as np
from matplotlib import pyplot as plt
import ants

# %%
cd ../Data/Genemaps
# Out:
# /mmfs1/data/pijarj/BC-ORG-Data/Data/Genemaps

# %%
diffmats = np.load('../../Data/Genemaps/CVAE_diffmats_S661.npy')
plt.imshow(diffmats[100,:,:])
plt.colorbar()

# %%
#NLGN4Y Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_22585_NLGN4Y_22829.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# -0.014154168013671696

# %%
#POGZ Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_22881_POGZ_23126.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.0336324567201691

# %%
#FMR1 Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_2316_FMR1_2332.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.07089743646044357

# %%
#CNTNAP2 Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_25796_CNTNAP2_26047.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.025755302472282863

# %%
#NLGN3 Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_33704_NLGN3_54413.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.03546364142088171

# %%
#NLGN4X Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_36775_NLGN4X_57502.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# 0.04320654048105783

# %%
#MECP2 Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_4179_MECP2_4204.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.013990757408908048

# %%
#MET Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_4208_MET_4233.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# 0.00874796711981705

# %%
#OXTR Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_4989_OXTR_5021.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.0017297663445810206

# %%
#RELN Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_5617_RELN_5649.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# 0.0016377718346356933

# %%
#SHANK3 Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_59528_SHANK3_85358.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.007176476485660352

# %%
#SLC6A4 Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_6496_SLC6A4_6532.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# -0.05976042774219048

# %%
#NRXN1 Gene
subject_diffmat = diffmats[0,:,:]
atlas = ants.image_read('../../YeoAtlas/Atlas_parc-7n_2mm.nii')
gene_im = ants.image_read('../../Data/Genemaps/gene_9243_NRXN1_9378.0.nii.gz')
gene_im.plot_ortho(flat=True,cmap='hot')
gene_flat = gene_im.numpy().flatten()
atlas_flat = atlas.numpy().flatten()
roi_expression = np.array([gene_flat[atlas_flat==roi].mean() for roi in np.arange(1,52)])
gene_sim = np.zeros((51,51))
for i in range(51):
    for j in range(51):
        gene_sim[i,j] = abs(roi_expression[i]-roi_expression[j])
plt.imshow(gene_sim)
triu = np.triu_indices(51,k=1)
gene_vec = gene_sim[triu]
fmri_vec = subject_diffmat[triu]
NRXN1_corr = np.corrcoef(gene_vec,fmri_vec)[0,1]
# Out:
# /data/pijarj/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
print('NLGN4Y correlation is', NLGN4Y_corr)
print('POGZ correlation is', POGZ_corr)
print('FMR1 correlation is', FMR1_corr)
print('CNTNAP2 correlation is', CNTNAP2_corr)
print('NLGN3 correlation is', NLGN3_corr)
print('NLGNX correlation is', NLGN4Y_corr)
print('MECP2 correlation is', POGZ_corr)
print('MET correlation is', FMR1_corr)
print('OXBR correlation is', CNTNAP2_corr)
print('RELN correlation is', NLGN3_corr)
print('SHANK3 correlation is', NLGN4Y_corr)
print('SLC6A4 correlation is', SLC6A4_corr)
print('NRXN1 correlation is', NRXN1_corr)
# Out:
# NLGN4Y correlation is -0.014154168013671696
# POGZ correlation is -0.0336324567201691
# FMR1 correlation is -0.07089743646044357
# CNTNAP2 correlation is -0.025755302472282863
# NLGN3 correlation is -0.03546364142088171
# NLGNX correlation is -0.014154168013671696
# MECP2 correlation is -0.0336324567201691
# MET correlation is -0.07089743646044357
# OXBR correlation is -0.025755302472282863
# RELN correlation is -0.03546364142088171
# SHANK3 correlation is -0.014154168013671696
# SLC6A4 correlation is -0.05976042774219048
# NRXN1 correlation is -0.05466848545078342

# %%
genes = [[NLGN4Y_corr,'NLGN4Y'], [POGZ_corr,'POGZ'], [FMR1_corr,'FMR1'], [CNTNAP2_corr,'CNTNAP2'], [NLGN3_corr,'NLGN3'], [NLGN4X_corr,'NLGN4X'], [MECP2_corr,'MECP2'], [MET_corr,'MET'], [OXTR_corr,'OXTR'], [RELN_corr,'RELN'], [SHANK3_corr,'SHANK3'], [SLC6A4_corr,'SLC6A4'], [NRXN1_corr,'NRXN1']]
genes.sort()
print(genes)
# Out:
# [[-0.07089743646044357, 'FMR1'], [-0.05976042774219048, 'SLC6A4'], [-0.05466848545078342, 'NRXN1'], [-0.03546364142088171, 'NLGN3'], [-0.0336324567201691, 'POGZ'], [-0.025755302472282863, 'CNTNAP2'], [-0.014154168013671696, 'NLGN4Y'], [-0.013990757408908048, 'MECP2'], [-0.007176476485660352, 'SHANK3'], [-0.0017297663445810206, 'OXTR'], [0.0016377718346356933, 'RELN'], [0.00874796711981705, 'MET'], [0.04320654048105783, 'NLGN4X']]

# %%
diffmats.shape
# Out:
# (661, 51, 51)
